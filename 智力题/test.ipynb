# %%
s = '0??1?'
ans = []

s_list = [i for i in s]

choice = ['0','1','2']
def f(s_list,i):#主递归
    if i == len(s):#到末尾了，搜集一种可能性
        if f2("".join(s_list)):
            ans.append("".join(s_list))
        return 
    if s_list[i] == '?':#如果遇到了问号
        for j in choice:#遍历所有的可能
            if j != s_list[i-1]:
                s_list[i] = j#替换掉一个
                f(s_list,i+1)
                s_list[i] = "?"
            else:
                continue     
    else:
        f(s_list,i+1)


def f2(s):#判断一个字符串是不是合法的
    for i in range(len(s)-1):
        if s[i] == s[i+1]:
            return False
    return True



f(s_list,0)
print(ans)
# Out:
# ['01010', '01012', '01210', '01212', '02010', '02012']
